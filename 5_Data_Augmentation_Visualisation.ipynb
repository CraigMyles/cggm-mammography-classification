# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tqdm import tqdm

width=10
height=10
rows = 6
cols = 5
axes=[]
fig = plt.figure(figsize=(12, 16))
plt.subplots_adjust(bottom=-0.5, top=0, hspace=0)

datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        rotation_range=20,
        zoom_range=0.33,
        horizontal_flip=True,
        vertical_flip=True
 )

img = load_img('/media/craig/6848080D4807D928/st_andrews/CMMD_dataset/subset_two/PNG/TRAIN/malignant/img_111.png')  # this is a PIL image
x = img_to_array(img)
x = x.reshape((1,) + x.shape)


i = 0
for batch in tqdm(datagen.flow(x, batch_size=1,
                          save_format='png')):
    b = batch.reshape((1,) + batch.shape)
    b = b[0, 0, :, :, 0]
    plt.subplot(rows,cols,i+1)
    plt.axis('off')
    plt.imshow(b, cmap=plt.cm.gray)
    
    i += 1
    if i >= 30:
        break
fig.tight_layout()
plt.savefig("./output/augmentation_30_set.png", dpi)
plt.show()
# Out:
# 29it [00:18,  1.59it/s]

# %%
def tick_params(letter):
    params = plt.tick_params(
    axis='both',
    which='both',
    bottom=False,
    top=False,
    left=False,
    right=False,
    labelbottom=False,
    labelleft=False)
    plt.ylabel('('+letter+')', fontsize=20)
    
    return params



fig = plt.figure(figsize=(12, 20))
columns = 3
rows = 5

img = mpimg.imread('./output/mammogram/original.png')
fig.add_subplot(rows, columns, 1)
plt.title('Original', fontsize=20)
tick_params("a")
plt.imshow(img)

img = mpimg.imread('./output/mammogram/arrow_right.png')
fig.add_subplot(rows, columns, 2)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/rotation_range.png')
fig.add_subplot(rows, columns, 3)
plt.title('rotation_range', fontsize=20)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/original.png')
fig.add_subplot(rows, columns, 4)
plt.title('Original', fontsize=20)
tick_params("b")
plt.imshow(img)

img = mpimg.imread('./output/mammogram/arrow_right.png')
fig.add_subplot(rows, columns, 5)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/zoom_range.png')
fig.add_subplot(rows, columns, 6)
plt.title('zoom_range', fontsize=20)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/original.png')
fig.add_subplot(rows, columns, 7)
plt.title('Original', fontsize=20)
tick_params("c")
plt.imshow(img)

img = mpimg.imread('./output/mammogram/arrow_right.png')
fig.add_subplot(rows, columns, 8)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/sheer_range.png')
fig.add_subplot(rows, columns, 9)
plt.title('sheer_range', fontsize=20)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/original.png')
fig.add_subplot(rows, columns, 10)
plt.title('Original', fontsize=20)
tick_params("d")
plt.imshow(img)

img = mpimg.imread('./output/mammogram/arrow_right.png')
fig.add_subplot(rows, columns, 11)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/vertical_flip.png')
fig.add_subplot(rows, columns, 12)
plt.title('vertical_flip', fontsize=20)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/original.png')
fig.add_subplot(rows, columns, 13)
plt.title('Original', fontsize=20)
tick_params("e")
plt.imshow(img)

img = mpimg.imread('./output/mammogram/arrow_right.png')
fig.add_subplot(rows, columns, 14)
plt.axis('off')
plt.imshow(img)

img = mpimg.imread('./output/mammogram/horizontal_flip.png')
fig.add_subplot(rows, columns, 15)
plt.title('horizontal_flip', fontsize=20)
plt.axis('off')
plt.imshow(img)

plt.savefig("./output/augmentation_table.png", dpi=150)
plt.show()
